# %% [markdown]
# <a href="https://colab.research.google.com/github/rat04/first-repo/blob/main/bigdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as msno

print(sys.version)
print(pd.__version__)
print(np.__version__)
print(sns.__version__)
print(msno.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 2.0.3
# 1.25.2
# 0.13.1
# 0.5.2

# %%
# !pip install koreanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 13.3 MB/s eta 0:00:00
# ...

# %%
# 그림 선명하게
# %config InlineBackend.figure_format = 'retina'

# %%
# 그림 해상도와 크기: 해상도를 높이면 크기에 비례에 커짐
import matplotlib.pyplot as plt

plt.rcParams.update({'figure.dpi' : '100'})             # 해상도, 기본값 72
plt.rcParams.update({'figure.figsize' : [18, 12]})      # 그림 크기, 기본값 [6, 4]

# %%
# 데이터프레임의 소수점 이하 n(2)자리 출력 설정
pd.set_option('display.precision', 2)

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-10, 5, -3, 1])
plt.title('그래프 제목')
plt.xlabel('직선')
plt.show()

# %%
import pandas as pd

kdriving = pd.read_csv('kdriving.csv')
titanic = pd.read_csv('titanic.csv')

# %%
import seaborn as sns

# %%
kdriving.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시점      10 non-null     int64
#  1   항목      10 non-null     object
#  2   서울      10 non-null     int64
#  3   남대전     10 non-null     int64
#  4   대전      10 non-null     int64
#  5   서대구     10 non-null     int64
#  6   북대구     10 non-null     int64
#  7   서울산     10 non-null     int64
#  8   부산      10 non-null     int64
#  9   북부산     10 non-null     int64
#  10  북대전     10 non-null     int64
#  11  서대전     10 non-null     int64
#  12  광주      10 non-null     int64
#  13  동서울     10 non-null     int64
#  14  서부산     10 non-null     int64
#  15  서서울     10 non-null     int64
#  16  동광주     10 non-null     int64
#  17  남대구     10 non-null     int64
#  18  북광주     10 non-null     int64
#  19  동대구     10 non-null     int64
#  20  대구      10 non-null     int64
#  21  울산      10 non-null     int64
# ...

# %%
kdriving.describe(include="all")
# Out:
#             시점            항목        서울       남대전        대전       서대구  \
# count     10.0            10  1.00e+01  1.00e+01  1.00e+01  1.00e+01
# unique     NaN            10       NaN       NaN       NaN       NaN
# top        NaN  이용차량(10KM미만)       NaN       NaN       NaN       NaN
# freq       NaN             1       NaN       NaN       NaN       NaN
# mean    2022.0           NaN  7.56e+06  5.66e+05  1.86e+06  2.25e+06
# std        0.0           NaN  1.11e+07  8.77e+05  2.72e+06  3.32e+06
# min     2022.0           NaN  4.33e+05  3.89e+02  5.56e+03  9.16e+03
# 25%     2022.0           NaN  1.23e+06  1.00e+05  4.27e+05  7.21e+05
# 50%     2022.0           NaN  4.09e+06  2.55e+05  1.30e+06  1.07e+06
# 75%     2022.0           NaN  8.24e+06  4.52e+05  1.78e+06  1.73e+06
# max     2022.0           NaN  3.78e+07  2.83e+06  9.32e+06  1.13e+07
#
#              북대구       서울산        부산       북부산  ...        광주       동서울  \
# ...

# %%
kdriving.count()
# Out:
# 시점     10
# 항목     10
# 서울     10
# 남대전    10
# 대전     10
# 서대구    10
# 북대구    10
# 서울산    10
# 부산     10
# 북부산    10
# 북대전    10
# 서대전    10
# 광주     10
# 동서울    10
# 서부산    10
# 서서울    10
# 동광주    10
# 남대구    10
# 북광주    10
# 동대구    10
# 대구     10
# 울산     10
# dtype: int64

# %%
kdriving.isna().sum()
# Out:
# 시점     0
# 항목     0
# 서울     0
# 남대전    0
# 대전     0
# 서대구    0
# 북대구    0
# 서울산    0
# 부산     0
# 북부산    0
# 북대전    0
# 서대전    0
# 광주     0
# 동서울    0
# 서부산    0
# 서서울    0
# 동광주    0
# 남대구    0
# 북광주    0
# 동대구    0
# 대구     0
# 울산     0
# dtype: int64

# %%
kdriving.head()
# Out:
#      시점             항목       서울      남대전       대전      서대구      북대구      서울산  \
# 0  2022   이용차량(10KM미만)   463780   113445   425611   536729   546202    68477
# 1  2022  이용차량(10-20KM)  8082559  1275538  1799641  1744674  3219100   831672
# 2  2022  이용차량(20-30KM)  8294565   506771  1554588  3678887  1731241   781002
# 3  2022  이용차량(30-40KM)  4446112   287723  1054695  1177028  2637094  1226452
# 4  2022  이용차량(40-50KM)  3732044    95520   430013   705750   328260   165347
#
#         부산      북부산  ...      광주      동서울      서부산      서서울      동광주      남대구  \
# 0   106748  4161525  ...  841071   338906   125838  9103385   755253  3515528
# 1  6661332  2526622  ...   39856  4137602  5154043  5526380  1006912  2312126
# 2   920332  1819438  ...  738102  7388225   667718  5488766  1534260  2532984
# 3  1776802  1790585  ...  490757  1835171   696544  1640395   634747  1248816
# 4   260802     5062  ...  505525  1636232  1370520  3215420   195739    78374
#
# ...

# %%
kdriving.shape
# Out:
# (10, 22)

# %%
import seaborn as sns
sns.scatterplot(data = kdriving, y = '서울', x='항목', alpha=.3);

# %%
sns.countplot(kdriving, x = "항목", hue = "부산", stat = "percent");

# %%
sns.countplot(kdriving, x = "항목", hue = "서울", stat = "percent");

# %%
sns.countplot(kdriving, x = "항목", hue = "울산", stat = "percent");

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.25        S   Third
# 1           1       1  female  38.0      1      0  71.28        C   First
# 2           1       3  female  26.0      0      0   7.92        S   Third
# 3           1       1  female  35.0      1      0  53.10        S   First
# 4           0       3    male  35.0      0      0   8.05        S   Third
# ..        ...     ...     ...   ...    ...    ...    ...      ...     ...
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 12))

axes[0][0].set_title("SibSp별 탑승자 수", size=15)
sns.countplot(x="SibSp", data=titanic, ax=axes[0][0], palette="Set2")
axes[0][1].set_title("Parch별 탑승자 수", size=15)
sns.countplot(x="Parch", data=titanic, ax=axes[0][1], palette="Set2")

axes[1][0].set_title("SibSp별 생존 여부", size=15)
sns.countplot(x="SibSp", hue="Survived", data=titanic, ax=axes[1][0], palette="Set2")
axes[1][0].legend(loc='upper right')
axes[1][1].set_title("Parch별 생존 여부", size=15)
sns.countplot(x="Parch", hue="Survived", data=titanic, ax=axes[1][1], palette="Set2")
axes[1][1].legend(loc='upper right')
# Out:
# <ipython-input-27-53da1cc2d48f>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="SibSp", data=titanic, ax=axes[0][0], palette="Set2")
# <ipython-input-27-53da1cc2d48f>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Parch", data=titanic, ax=axes[0][1], palette="Set2")
